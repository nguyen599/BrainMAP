# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import os
import pandas as pd
# 设置字体和大小
rcParams['font.family'] = 'Times New Roman'
rcParams['font.size'] = 25
plt.rcParams['mathtext.fontset'] = 'stix'  # Options: 'stix', 'stixsans', 'cm' (Computer Modern), 'dejavusans'
plt.rcParams['mathtext.default'] = 'regular'  # Use regular weight for math fonts

# data loading 1. group 2. acc+ delta_sp .loc rank 3.average of three files 

data1 = [94.45, 94.48, 94.74, 94.70, 94.71, 94.75]


fig = plt.figure(figsize=(0.73 * 6, 0.73 * 3))

bar_width = 0.4
x_labels = data1

x1 = np.arange(len(data1))
x1 = [x  for x in x1]
# x2 = [x + bar_width for x in x1]
# x3 = [x + bar_width for x in x2]
# x4 = [x + bar_width for x in x3]

print(x1)

bar_container = plt.bar(x1, data1, width=bar_width, label=data1, color=(130/255.0, 176/255.0, 210/255.0), edgecolor="black", linewidth=1.3, capsize=2)


# 设置背景颜色为浅灰色
plt.gca().set_facecolor('#EEF0F2')

# 开启网格，并设置虚线样式和颜色
plt.grid(True, linestyle='--', color='gray', alpha=0.5)


# 设置坐标轴标签
# plt.xlabel('Number of Experts', fontsize=15)  # 修改x轴名称，加粗并修改为斜体X
plt.ylabel('Accuracy', fontsize=25)


# plt.ylim(0, 80)

plt.xticks([r for r in range(len(data1))], [1,2,3,4,5,6])

# plt.legend()
# plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# 设置y轴显示范围为0到1，均匀划分四份来呈现网格
plt.ylim(94.2, 95)
fmt = lambda x: "{:.1f}".format(x)
# plt.yticks(np.linspace(0, 10, 5), [fmt(i) for i in np.linspace(0, 10, 5)])


def custom_formatter(x, pos):
    return f'{x:.2f}'

# 移除上方和右侧的边框
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='y', which='major', labelsize=20)
ax.yaxis.set_major_formatter(custom_formatter)
ax.tick_params(axis='x', which='major', labelsize=20)

# plt.legend(fontsize=13, borderpad=0.3, labelspacing=0.1, ncol=4, columnspacing=1.33, handletextpad=0.3, loc=(0.02, 0.8))
        #    , handlelength=1, handleheight=0.5)
plt.savefig('layer_a.pdf', dpi=600, format= 'pdf', bbox_inches='tight')
plt.show()
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import os
import pandas as pd
# 设置字体和大小
rcParams['font.family'] = 'Times New Roman'
rcParams['font.size'] = 20
plt.rcParams['mathtext.fontset'] = 'stix'  # Options: 'stix', 'stixsans', 'cm' (Computer Modern), 'dejavusans'
plt.rcParams['mathtext.default'] = 'regular'  # Use regular weight for math fonts

# data loading 1. group 2. acc+ delta_sp .loc rank 3.average of three files 

data1 = [78.09, 78.7, 78.92, 79.01, 79.01, 79.01]


fig = plt.figure(figsize=(0.73 * 6, 0.73 * 3))

bar_width = 0.4
x_labels = data1

x1 = np.arange(len(data1))
x1 = [x  for x in x1]
# x2 = [x + bar_width for x in x1]
# x3 = [x + bar_width for x in x2]
# x4 = [x + bar_width for x in x3]

print(x1)

bar_container = plt.bar(x1, data1, width=bar_width, label=data1, color=(130/255.0, 176/255.0, 210/255.0), edgecolor="black", linewidth=1.3, capsize=2)


# 设置背景颜色为浅灰色
plt.gca().set_facecolor('#EEF0F2')

# 开启网格，并设置虚线样式和颜色
plt.grid(True, linestyle='--', color='gray', alpha=0.5)


# 设置坐标轴标签
# plt.xlabel('Number of Experts', fontsize=15)  # 修改x轴名称，加粗并修改为斜体X
plt.ylabel('Accuracy', fontsize=25)


# plt.ylim(0, 80)

plt.xticks([r for r in range(len(data1))], [1,2,3,4,5, 6])

# plt.legend()
# plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# 设置y轴显示范围为0到1，均匀划分四份来呈现网格
plt.ylim(78, 79.3)
fmt = lambda x: "{:.1f}".format(x)
# plt.yticks(np.linspace(0, 10, 5), [fmt(i) for i in np.linspace(0, 10, 5)])

# 移除上方和右侧的边框
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='y', which='major', labelsize=20)
ax.yaxis.set_major_formatter(custom_formatter)
ax.tick_params(axis='x', which='major', labelsize=20)

# plt.legend(fontsize=13, borderpad=0.3, labelspacing=0.1, ncol=4, columnspacing=1.33, handletextpad=0.3, loc=(0.02, 0.8))
        #    , handlelength=1, handleheight=0.5)
plt.savefig('layer_b.pdf', dpi=600, format= 'pdf', bbox_inches='tight')
plt.show()
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import os
import pandas as pd
# 设置字体和大小
rcParams['font.family'] = 'Times New Roman'
rcParams['font.size'] = 20
plt.rcParams['mathtext.fontset'] = 'stix'  # Options: 'stix', 'stixsans', 'cm' (Computer Modern), 'dejavusans'
plt.rcParams['mathtext.default'] = 'regular'  # Use regular weight for math fonts

# data loading 1. group 2. acc+ delta_sp .loc rank 3.average of three files 

data1 = [11.19, 11.14, 10.75, 10.65, 10.625, 10.63]


fig = plt.figure(figsize=(0.73 * 6, 0.73 * 3))

bar_width = 0.4
x_labels = data1

x1 = np.arange(len(data1))
x1 = [x  for x in x1]
# x2 = [x + bar_width for x in x1]
# x3 = [x + bar_width for x in x2]
# x4 = [x + bar_width for x in x3]

print(x1)

bar_container = plt.bar(x1, data1, width=bar_width, label=data1, color=(142/255.0, 207/255.0, 201/255.0), edgecolor="black", linewidth=1.3, capsize=2)


# 设置背景颜色为浅灰色
plt.gca().set_facecolor('#EEF0F2')

# 开启网格，并设置虚线样式和颜色
plt.grid(True, linestyle='--', color='gray', alpha=0.5)


# 设置坐标轴标签
# plt.xlabel('Number of Experts', fontsize=15)  # 修改x轴名称，加粗并修改为斜体X
plt.ylabel('MAE', fontsize=25)


# plt.ylim(0, 80)

plt.xticks([r for r in range(len(data1))], [1,2,3,4,5, 6])

# plt.legend()
# plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# 设置y轴显示范围为0到1，均匀划分四份来呈现网格
plt.ylim(10.2, 11.5)
fmt = lambda x: "{:.1f}".format(x)
# plt.yticks(np.linspace(0, 10, 5), [fmt(i) for i in np.linspace(0, 10, 5)])

# 移除上方和右侧的边框
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='y', which='major', labelsize=20)
ax.yaxis.set_major_formatter(custom_formatter)
ax.tick_params(axis='x', which='major', labelsize=20)

# plt.legend(fontsize=13, borderpad=0.3, labelspacing=0.1, ncol=4, columnspacing=1.33, handletextpad=0.3, loc=(0.02, 0.8))
        #    , handlelength=1, handleheight=0.5)
plt.savefig('layer_c.pdf', dpi=600, format= 'pdf', bbox_inches='tight')
plt.show()
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import os
import pandas as pd
# 设置字体和大小
rcParams['font.family'] = 'Times New Roman'
rcParams['font.size'] = 20
plt.rcParams['mathtext.fontset'] = 'stix'  # Options: 'stix', 'stixsans', 'cm' (Computer Modern), 'dejavusans'
plt.rcParams['mathtext.default'] = 'regular'  # Use regular weight for math fonts

# data loading 1. group 2. acc+ delta_sp .loc rank 3.average of three files 

data1 = [3.91, 3.83, 3.81, 3.8, 3.79, 3.78]


fig = plt.figure(figsize=(0.73 * 6, 0.73 * 3))

bar_width = 0.4
x_labels = data1

x1 = np.arange(len(data1))
x1 = [x  for x in x1]
# x2 = [x + bar_width for x in x1]
# x3 = [x + bar_width for x in x2]
# x4 = [x + bar_width for x in x3]

print(x1)

bar_container = plt.bar(x1, data1, width=bar_width, label=data1, color=(142/255.0, 207/255.0, 201/255.0), edgecolor="black", linewidth=1.3, capsize=2)


# 设置背景颜色为浅灰色
plt.gca().set_facecolor('#EEF0F2')

# 开启网格，并设置虚线样式和颜色
plt.grid(True, linestyle='--', color='gray', alpha=0.5)


# 设置坐标轴标签
# plt.xlabel('Number of Experts', fontsize=15)  # 修改x轴名称，加粗并修改为斜体X
plt.ylabel('MAE', fontsize=25)


# plt.ylim(0, 80)

plt.xticks([r for r in range(len(data1))], [1,2,3,4,5, 6])

# plt.legend()
# plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# 设置y轴显示范围为0到1，均匀划分四份来呈现网格
plt.ylim(3.7, 4.0)
fmt = lambda x: "{:.1f}".format(x)
# plt.yticks(np.linspace(0, 10, 5), [fmt(i) for i in np.linspace(0, 10, 5)])

# 移除上方和右侧的边框
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='y', which='major', labelsize=20)
ax.yaxis.set_major_formatter(custom_formatter)
ax.tick_params(axis='x', which='major', labelsize=20)

# plt.legend(fontsize=13, borderpad=0.3, labelspacing=0.1, ncol=4, columnspacing=1.33, handletextpad=0.3, loc=(0.02, 0.8))
        #    , handlelength=1, handleheight=0.5)
plt.savefig('layer_d.pdf', dpi=600, format= 'pdf', bbox_inches='tight')
plt.show()
# Out:
# [0, 1, 2, 3, 4, 5]
